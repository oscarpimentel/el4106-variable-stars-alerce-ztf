# %% [markdown]
# # ALeRCE classes
#
# https://github.com/ZwickyTransientFacility/ztf-avro-alert
#
# 1. **AGN:** Active Galactic Nuclei
# 1. **Blazar:** Blazar
# 1. **CV/Nova:** Cataclysmic Variable Star/Nova
# 1. **Ceph: Cepheid Variable Star**
# 1. **DSCT: Delta Scuti Star**
# 1. **EA:** Eclipsing Algol
# 1. **EB/EW: Eclipsing Binaries/Eclipsing W Ursa Majoris**
# 1. **LPV: Long Period Variable**
# 1. **Periodic-Other:** Periodic-Other
# 1. **QSO:** Quasi-Stellar Object
# 1. **RRL: RRLyrae Variable Star**
# 1. **RSCVn:** RS Canum Venaticorum
# 1. **SLSN:** Super Luminous Supernova
# 1. **SNII:** Supernova II
# 1. **SNIIb:** Supernova IIb
# 1. **SNIIn:** Supernova IIn
# 1. **SNIa:** Supernova Ia
# 1. **SNIbc:** Supernova Ibc
# 1. **TDE:** Tidal disruption event (to remove)
# 1. **YSO:** Young Stellar Object
# 1. **ZZ:** ZZ Ceti Stars (to remove)

# %% [markdown]
# # Columns names
# 1. **oid:** object id
# 1. **classALeRCE:** object class name
# 1. **fid:** band index, g=1, r=2
# 1. **mjd:** observation day in mjd format
# 1. **magpsf_corr:** observations in aparent magnitude
# 1. **sigmapsf_corr:** observation errors in aparent magnitude

# %%
import sys
sys.path.append('../')
sys.path.append('../../')

# %%
import numpy as np
import pandas as pd
            
#survey_name = 'alerceZTFv5.1'
survey_name = 'alerceZTFv7.1' # use this dataset

### load files
load_root_dir = f'../data/{survey_name}'
labels_df = pd.read_parquet(f'{load_root_dir}/labels_vs.parquet')
print(f'labels_df - columns: {list(labels_df.columns)} - id: {labels_df.index.name}')
detections_df = pd.read_parquet(f'{load_root_dir}/detections_vs.parquet')
print(f'detections_df - columns: {list(detections_df.columns)} - id: {detections_df.index.name}')

### print info
classes = set(labels_df['classALeRCE'].values)
print('classes:', classes)
# Out:
# labels_df - columns: ['classALeRCE', 'ra', 'dec', 'period', 'source', 'id_source', 'class_source', 'separation_arcsec'] - id: oid
# detections_df - columns: ['fid', 'mjd', 'magpsf_corr', 'sigmapsf_corr'] - id: oid
# classes: {'DSCT', 'EB/EW', 'LPV', 'RRL', 'Ceph'}

# %%
print(detections_df.info())
detections_df[:20]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5285267 entries, ZTF17aaafyya to ZTF20abceckn
# Data columns (total 4 columns):
# fid              int64
# mjd              float32
# magpsf_corr      float32
# sigmapsf_corr    float32
# dtypes: float32(3), int64(1)
# memory usage: 141.1+ MB
# None
#               fid           mjd  magpsf_corr  sigmapsf_corr
# oid
# ZTF17aaafyya    1  58791.285156    15.262988       0.004987
# ZTF17aaafyya    1  59081.468750    15.281164       0.007919
# ZTF17aaafyya    1  59067.402344    15.245437       0.000493
# ZTF17aaafyya    1  58793.250000    15.205706       0.010043
# ZTF17aaafyya    1  58793.238281    15.228786       0.009911
# ZTF17aaafyya    1  58747.324219    15.226640       0.009151
# ZTF17aaafyya    1  58334.472656    15.233562       0.009774
# ZTF17aaafyya    1  58677.472656    15.276610       0.009193
# ZTF17aaafyya    1  58332.464844    15.212075       0.003076
# ZTF17aaafyya    1  58831.203125    15.287753       0.005032
# ZTF17aaafyya    1  58674.449219    15.288366       0.001313
# ZTF17aaafyya    1  58360.449219    15.193118       0.010500
# ZTF17aaafyya    1  58424.191406    15.244930       0.013392
# ZTF17aaafyya    1  58440.218750    15.210513       0.008202
# ZTF17aaafyya    1  59067.414062    15.262165       0.002096
# ZTF17aaafyya    1  58690.472656    15.242799       0.009232
# ZTF17aaafyya    1  58522.140625    15.204104       0.004220
# ZTF17aaafyya    1  58814.238281    15.290370       0.012436
# ZTF17aaafyya    1  59076.453125    15.244116       0.008676
# ZTF17aaafyya    1  59072.378906    15.247376       0.004940

# %%
print(labels_df.info())
labels_df[:20]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 82381 entries, ZTF18abwwdsc to ZTF18abgqxlw
# Data columns (total 8 columns):
# classALeRCE          82381 non-null object
# ra                   82381 non-null float32
# dec                  82381 non-null float32
# period               59985 non-null object
# source               82381 non-null object
# id_source            82381 non-null object
# class_source         82381 non-null object
# separation_arcsec    82381 non-null float32
# dtypes: float32(3), object(5)
# memory usage: 4.7+ MB
# None
#              classALeRCE          ra        dec     period     source  \
# oid
# ZTF18abwwdsc        Ceph  326.755859  -8.060673    2.18895  CRTSnorth
# ZTF18aaakigd        Ceph   65.440018  34.069809    2.11360  CRTSnorth
# ZTF18aaavkyj        Ceph  192.885040  24.122641    1.09572  CRTSnorth
# ZTF18abwwdxw        Ceph  324.865967 -17.296144    1.11714  CRTSnorth
# ZTF19aaocniv        Ceph  248.580612 -16.015739  1.3049582  CRTSnorth
# ZTF17aacemqz        Ceph  117.977669  27.561363    16.2488  CRTSnorth
# ZTF18aaiyfjx        Ceph  245.464371  38.909588    1.04986  CRTSnorth
# ZTF19aaczymt        Ceph  228.810760 -14.901231  4.3680244  CRTSnorth
# ZTF18abvpirg        Ceph  351.955292  -9.388095    119.947  CRTSnorth
# ZTF18abccnft        Ceph  330.037994   9.169602    1.11004  CRTSnorth
# ZTF18aazzfhx        Ceph  257.629730  22.385666    1.19145  CRTSnorth
# ZTF18abvtdoa        Ceph   70.660568  -6.803840  18.164585  CRTSnorth
# ZTF18absvbuc        Ceph  312.391785   6.591703  1.9025178  CRTSnorth
# ZTF18abmxafi        Ceph  254.760727   4.791575  1.7756249  CRTSnorth
# ZTF18acpewdw        Ceph    7.230485  43.033501    1.17812  CRTSnorth
# ZTF18abhqdkc        Ceph  340.741882  20.988482  10.100843  CRTSnorth
# ZTF18acrmlma        Ceph  154.063080   2.541418  188.55902  CRTSnorth
# ZTF18accipen        Ceph  350.990631  17.756960  0.9108870  CRTSnorth
# ZTF18aagwwiq        Ceph  261.553345  34.654068  1.1374796  CRTSnorth
# ZTF17aadfivr        Ceph   79.339935  15.578883    0.89541  CRTSnorth
#
#                     id_source class_source  separation_arcsec
# oid
# ZTF18abwwdsc  1007116010622.0       Cep-II           0.676851
# ZTF18aaakigd  1135020009815.0         ACEP           0.390734
# ZTF18aaavkyj  1123064031941.0         ACEP           0.291110
# ZTF18abwwdxw  1018112055304.0         ACEP           1.881608
# ZTF19aaocniv  1015086048064.0       Cep-II           0.405458
# ZTF17aacemqz  1126038065052.0       Cep-II           1.092943
# ZTF18aaiyfjx  1138071060852.0       Cep-II           0.610218
# ZTF19aaczymt  1015079060794.0       Cep-II           0.422664
# ZTF18abvpirg  1009125035570.0       Cep-II           0.266861
# ZTF18abccnft  1109117020606.0         ACEP           0.759991
# ZTF18aazzfhx  1121087098549.0         ACEP           0.727519
# ZTF18abvtdoa  1007025037059.0       Cep-II           0.488417
# ZTF18absvbuc  1107111042642.0       Cep-II           0.621413
# ZTF18abmxafi  1104091091235.0         ACEP           1.038624
# ZTF18acpewdw  1143002023753.0       Cep-II           0.799297
# ZTF18abhqdkc  1121115034187.0       Cep-II           0.159369
# ZTF18acrmlma  1101055057397.0       Cep-II           0.335061
# ZTF18accipen  1118120020026.0       Cep-II           1.875137
# ZTF18aagwwiq  1135078029796.0         ACEP           0.825942
# ZTF17aadfivr  1115028059992.0       Cep-II           0.473645

# %%
# %load_ext autoreload
# %autoreload 2
from vstars import C_
from vstars.utils import get_object
import matplotlib.pyplot as plt
from dask import dataframe as dd

### example using dask
detections_ddf = dd.from_pandas(detections_df, npartitions=C_.N_DASK) # dask dataframe can be faster
labels_ddf = dd.from_pandas(labels_df, npartitions=C_.N_DASK) # dask dataframe can be faster
obj_name = 'ZTF18abvpirg'
band = 1
days, obs, obs_error, c = get_object(detections_ddf, labels_ddf, obj_name, band)

color = 'k'
fig, ax = plt.subplots(1, 1, figsize=(10,4))
ax.plot(days, obs, 'o--', c=color)
ax.errorbar(days, obs, yerr=obs_error, color=color, capsize=0, elinewidth=1, linewidth=0)
ax.set_title(f'obj: {obj_name} - class: {c} - band: {band}')
plt.show()
print(labels_df.loc[obj_name])
print(detections_df.loc[obj_name])
# Out:
# classALeRCE                     Ceph
# ra                           351.955
# dec                         -9.38809
# period                       119.947
# source                     CRTSnorth
# id_source            1009125035570.0
# class_source                  Cep-II
# separation_arcsec           0.266861
# Name: ZTF18abvpirg, dtype: object
#               fid           mjd  magpsf_corr  sigmapsf_corr
# oid
# ZTF18abvpirg    1  58429.207031    16.720863       0.021344
# ZTF18abvpirg    1  58423.214844    16.577658       0.018441
# ZTF18abvpirg    1  58760.335938    16.890135       0.017367
# ZTF18abvpirg    1  58426.207031    16.651241       0.028777
# ZTF18abvpirg    1  58646.441406    16.812498       0.021536
# ZTF18abvpirg    1  58772.285156    16.586370       0.068318
# ZTF18abvpirg    1  58670.441406    16.893030       0.015404
# ZTF18abvpirg    1  58785.214844    16.735077       0.020320
# ZTF18abvpirg    1  58660.457031    16.702377       0.012981
# ZTF18abvpirg    1  58437.230469    17.025349       0.023844
# ZTF18abvpirg    1  58775.183594    16.667181       0.023293
